# %%
import pandas as pd
movies=pd.read_csv('http://bit.ly/imdbratings')
movies.shape
# Out:
# (979, 6)

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.title
# Out:
# 0                               The Shawshank Redemption
# 1                                          The Godfather
# 2                                 The Godfather: Part II
# 3                                        The Dark Knight
# 4                                           Pulp Fiction
# 5                                           12 Angry Men
# 6                         The Good, the Bad and the Ugly
# 7          The Lord of the Rings: The Return of the King
# 8                                       Schindler's List
# 9                                             Fight Club
# 10     The Lord of the Rings: The Fellowship of the Ring
# 11                                             Inception
# 12        Star Wars: Episode V - The Empire Strikes Back
# 13                                          Forrest Gump
# 14                 The Lord of the Rings: The Two Towers
# 15                                          Interstellar
# ...

# %%
import pandas as pd
ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %%
ufo['City']
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
# 5                 Valley City
# 6                 Crater Lake
# 7                        Alma
# 8                     Eklutna
# 9                     Hubbard
# 10                    Fontana
# 11                   Waterloo
# 12                     Belton
# 13                     Keokuk
# 14                  Ludington
# 15                Forest Home
# 16                Los Angeles
# 17                  Hapeville
# 18                     Oneida
# 19                 Bering Sea
# 20                   Nebraska
# 21                        NaN
# 22                        NaN
# 23                  Owensboro
# 24                 Wilderness
# 25                  San Diego
# 26                 Wilderness
# 27                     Clovis
# 28                 Los Alamos
# 29               Ft. Duschene
#                  ...
# ...

# %%
ufo.City
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
# 5                 Valley City
# 6                 Crater Lake
# 7                        Alma
# 8                     Eklutna
# 9                     Hubbard
# 10                    Fontana
# 11                   Waterloo
# 12                     Belton
# 13                     Keokuk
# 14                  Ludington
# 15                Forest Home
# 16                Los Angeles
# 17                  Hapeville
# 18                     Oneida
# 19                 Bering Sea
# 20                   Nebraska
# 21                        NaN
# 22                        NaN
# 23                  Owensboro
# 24                 Wilderness
# 25                  San Diego
# 26                 Wilderness
# 27                     Clovis
# 28                 Los Alamos
# 29               Ft. Duschene
#                  ...
# ...

# %%
type(ufo['City'])
# Out:
# pandas.core.series.Series

# %%
ufo['Colors Reported']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          RED
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          RED
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
#           ...
# 18211       NaN
# 18212       NaN
# 18213     GREEN
# 18214       NaN
# 18215       NaN
# 18216    ORANGE
# 18217       NaN
# 18218       NaN
# 18219       NaN
# 18220      BLUE
# 18221       NaN
# 18222       NaN
# 18223       NaN
# 18224       NaN
# 18225       NaN
# 18226       NaN
# 18227       NaN
# 18228       NaN
# 18229       NaN
# 18230       NaN
# 18231       NaN
# 18232       NaN
# 18233       RED
# 18234       NaN
# ...

# %%
ufo['another col']=ufo.City+',' +ufo.State
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                another col
# 0                Ithaca,NY
# 1           Willingboro,NJ
# 2               Holyoke,CO
# 3               Abilene,KS
# 4  New York Worlds Fair,NY

# %%
ufo.describe()
# Out:
#            City Colors Reported Shape Reported  State              Time  \
# count     18216            2882          15597  18241             18241
# unique     6476              27             27     52             16145
# top     Seattle             RED          LIGHT     CA  11/16/1999 19:00
# freq        187             780           2803   2529                27
#
#        another col
# count        18216
# unique        8029
# top     Seattle,WA
# freq           187

# %%
ufo.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# another col        object
# dtype: object

# %%
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %%
ufo.describe(include = ['object'])
# Out:
#            City Colors Reported Shape Reported  State              Time  \
# count     18216            2882          15597  18241             18241
# unique     6476              27             27     52             16145
# top     Seattle             RED          LIGHT     CA  11/16/1999 19:00
# freq        187             780           2803   2529                27
#
#        another col
# count        18216
# unique        8029
# top     Seattle,WA
# freq           187

# %%
ufo.columns
ufo_col = ['city','CR','SR','state','time','extra']
ufo.columns=ufo_col
ufo.head()
# Out:
#                    city   CR        SR state             time  \
# 0                Ithaca  NaN  TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro  NaN     OTHER    NJ  6/30/1930 20:00
# 2               Holyoke  NaN      OVAL    CO  2/15/1931 14:00
# 3               Abilene  NaN      DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair  NaN     LIGHT    NY  4/18/1933 19:00
#
#                      extra
# 0                Ithaca,NY
# 1           Willingboro,NJ
# 2               Holyoke,CO
# 3               Abilene,KS
# 4  New York Worlds Fair,NY

# %%
ufo.rename(columns={'Colors Reported':'CR','Shape Reported':'SR'})
# Out:
#                        City      CR         SR State              Time  \
# 0                    Ithaca     NaN   TRIANGLE    NY    6/1/1930 22:00
# 1               Willingboro     NaN      OTHER    NJ   6/30/1930 20:00
# 2                   Holyoke     NaN       OVAL    CO   2/15/1931 14:00
# 3                   Abilene     NaN       DISK    KS    6/1/1931 13:00
# 4      New York Worlds Fair     NaN      LIGHT    NY   4/18/1933 19:00
# 5               Valley City     NaN       DISK    ND   9/15/1934 15:30
# 6               Crater Lake     NaN     CIRCLE    CA    6/15/1935 0:00
# 7                      Alma     NaN       DISK    MI    7/15/1936 0:00
# 8                   Eklutna     NaN      CIGAR    AK  10/15/1936 17:00
# 9                   Hubbard     NaN   CYLINDER    OR    6/15/1937 0:00
# 10                  Fontana     NaN      LIGHT    CA   8/15/1937 21:00
# 11                 Waterloo     NaN   FIREBALL    AL    6/1/1939 20:00
# ...

# %%
ufo = pd.read_csv('http://bit.ly/uforeports',names=ufo_cols)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-5441893fb868> in <module>()
# ----> 1 ufo = pd.read_csv('http://bit.ly/uforeports',names=ufo_cols)
#
# NameError: name 'ufo_cols' is not defined

# %%
ufo.columns
# Out:
# Index(['city', 'CR', 'SR', 'state', 'time', 'extra'], dtype='object')

# %%
ufo.drop([0,1],axis=0)
# Out:
#                        city      CR         SR state              time  \
# 2                   Holyoke     NaN       OVAL    CO   2/15/1931 14:00
# 3                   Abilene     NaN       DISK    KS    6/1/1931 13:00
# 4      New York Worlds Fair     NaN      LIGHT    NY   4/18/1933 19:00
# 5               Valley City     NaN       DISK    ND   9/15/1934 15:30
# 6               Crater Lake     NaN     CIRCLE    CA    6/15/1935 0:00
# 7                      Alma     NaN       DISK    MI    7/15/1936 0:00
# 8                   Eklutna     NaN      CIGAR    AK  10/15/1936 17:00
# 9                   Hubbard     NaN   CYLINDER    OR    6/15/1937 0:00
# 10                  Fontana     NaN      LIGHT    CA   8/15/1937 21:00
# 11                 Waterloo     NaN   FIREBALL    AL    6/1/1939 20:00
# 12                   Belton     RED     SPHERE    SC   6/30/1939 20:00
# 13                   Keokuk     NaN       OVAL    IA     7/7/1939 2:00
# ...

# %%
ufo.columns
# Out:
# Index(['city', 'CR', 'SR', 'state', 'time', 'extra'], dtype='object')

# %%
ufo.sort_values(['time','city'])
# Out:
#                              city            CR         SR state  \
# 24                     Wilderness           NaN       DISK    WV
# 25                      San Diego           NaN      CIGAR    CA
# 26                     Wilderness           NaN       DISK    WV
# 32                        Ft. Lee           NaN      CIGAR    VA
# 118                    Mount Hope           NaN        NaN    WV
# 170                Salt Lake City           NaN        NaN    UT
# 222                      Nebraska           NaN        NaN    NE
# 223                      Oklahoma           NaN      CIGAR    TX
# 258                     Brunswick           NaN        NaN    ME
# 259                      Lakeland           NaN       DISK    FL
# 260                    Souix City           NaN     CIRCLE    IA
# 346                       Weirton           NaN       DISK    WV
# 392                        Dallas           NaN        NaN    TX
# ...

# %%
import pandas as pd
movies =pd.read_csv('http://bit.ly/imdbratings')
movies.columns
movies.shape
# Out:
# (979, 6)

# %%
movies[(movies.duration>=200)|
       (movies.genre=='Drama')]
# Out:
#      star_rating                                           title  \
# 2            9.1                          The Godfather: Part II
# 5            8.9                                    12 Angry Men
# 7            8.9   The Lord of the Rings: The Return of the King
# 9            8.9                                      Fight Club
# 13           8.8                                    Forrest Gump
# 16           8.7                 One Flew Over the Cuckoo's Nest
# 17           8.7                                   Seven Samurai
# 22           8.7                           It's a Wonderful Life
# 24           8.7                                           Se7en
# 27           8.6                        The Silence of the Lambs
# 32           8.6                                      Casablanca
# 33           8.6                                        Whiplash
# 41           8.5                                    Sunset Blvd.
# ...

# %%
movies[movies.genre.isin(['Drama','Crime'])]
# Out:
#      star_rating                                           title  \
# 0            9.3                        The Shawshank Redemption
# 1            9.2                                   The Godfather
# 2            9.1                          The Godfather: Part II
# 4            8.9                                    Pulp Fiction
# 5            8.9                                    12 Angry Men
# 9            8.9                                      Fight Club
# 13           8.8                                    Forrest Gump
# 16           8.7                 One Flew Over the Cuckoo's Nest
# 17           8.7                                   Seven Samurai
# 21           8.7                                     City of God
# 22           8.7                           It's a Wonderful Life
# 23           8.7                              The Usual Suspects
# 24           8.7                                           Se7en
# ...

# %%
movies.mean()
# Out:
# star_rating      7.889785
# duration       120.979571
# dtype: float64

# %%
movies.mean(axis=1)
# Out:
# 0       75.65
# 1       92.10
# 2      104.55
# 3       80.50
# 4       81.45
# 5       52.45
# 6       84.95
# 7      104.95
# 8      101.95
# 9       73.95
# 10      93.40
# 11      78.40
# 12      66.40
# 13      75.40
# 14      93.90
# 15      88.85
# 16      70.85
# 17     107.85
# 18      77.35
# 19      64.85
# 20      72.35
# 21      69.35
# 22      69.35
# 23      57.35
# 24      67.85
# 25      62.30
# 26      91.80
# 27      63.30
# 28      59.30
# 29      47.80
#         ...
# 949     55.20
# 950     57.70
# 951     56.20
# 952     62.20
# 953     54.70
# 954     55.70
# 955     82.20
# 956     55.70
# 957     52.70
# 958     58.20
# 959     51.70
# 960     55.20
# 961     60.70
# 962     53.20
# 963     62.70
# 964     78.70
# 965     56.20
# 966     47.20
# 967     71.70
# 968     84.70
# 969     58.20
# 970     57.20
# 971     48.70
# 972     59.70
# 973     66.70
# 974     61.70
# 975     62.70
# 976     72.70
# 977     60.70
# 978     66.70
# dtype: float64

# %%
movies.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
movies.genre.str.replace('Drama','dr').str.replace('Crime','cr')
# Out:
# 0             cr
# 1             cr
# 2             cr
# 3         Action
# 4             cr
# 5             dr
# 6        Western
# 7      Adventure
# 8      Biography
# 9             dr
# 10     Adventure
# 11        Action
# 12        Action
# 13            dr
# 14     Adventure
# 15     Adventure
# 16            dr
# 17            dr
# 18     Biography
# 19        Action
# 20        Action
# 21            cr
# 22            dr
# 23            cr
# 24            dr
# 25        Comedy
# 26       Western
# 27            dr
# 28            cr
# 29        Comedy
#          ...
# 949       Comedy
# 950           cr
# 951           dr
# 952       Comedy
# 953    Adventure
# 954       Action
# 955           dr
# 956       Comedy
# 957       Comedy
# 958           dr
# 959       Comedy
# 960       Comedy
# 961    Biography
# 962       Comedy
# 963       Action
# 964    Biography
# 965      Mystery
# 966    Animation
# 967       Action
# 968           dr
# 969           cr
# ...

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies.groupby('genre').duration.min()
# Out:
# genre
# Action        80
# Adventure     89
# Animation     75
# Biography     85
# Comedy        68
# Crime         67
# Drama         64
# Family       100
# Fantasy      112
# Film-Noir     88
# History       66
# Horror        70
# Mystery       69
# Sci-Fi        91
# Thriller     107
# Western       85
# Name: duration, dtype: int64

# %%
# %matplotlib inline

# %%
movies.groupby('genre').mean().plot(kind='bar')

# %%
movies.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64
